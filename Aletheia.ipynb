# %% [markdown]
# ## Borrador para software de análisis de datos cualitativos ##

# %% [markdown]
# ### Objetivo: diseñar una herramienta que permita hacer todo el trabajo de un software de análisis cualitativo pero que sea open source de código abierto, de manera que pueda ser accesible para investigadores de las ciencias sociales. ###

# %%
import streamlit as st
import pandas as pd
import spacy
from collections import Counter

# %%
pip install spacy streamlit pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install spacy
# !python -m download es_core_news_sm
# Out:
# ...
# C:\Users\user\anaconda3\python.exe: No module named download

# %%
st.set_page_config(page_title="Aletheia Qualitative", layout="wide")
# Out:
# 2026-03-01 21:11:12.808 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
col1, col2 = st.columns([2, 1])
# Out:
# 2026-03-01 21:11:16.373 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-01 21:11:16.375 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-01 21:11:16.376 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !python -m spacy download es_core_news_sm
nlp = spacy.load("es_core_news_sm")
doc = nlp(raw_text)
keywords = [token.text.lower() for token in doc if token.is_alpha and not token.is_stop]
st.bar_chart(df_viz.set_index('Concepto'))
# Out:
# ...
# ERROR: Could not install packages due to an OSError: HTTPSConnectionPool(host='github.com', port=443): Max retries exceeded with url: /explosion/spacy-models/releases/download/es_core_news_sm-3.8.0/es_core_news_sm-3.8.0-py3-none-any.whl (Caused by ResponseError('too many 502 error responses'))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 get_ipython().system('python -m spacy download es_core_news_sm')
#       2 nlp = spacy.load("es_core_news_sm")
# ----> 3 doc = nlp(raw_text)
#       4 keywords = [token.text.lower() for token in doc if token.is_alpha and not token.is_stop]
#       5 st.bar_chart(df_viz.set_index('Concepto'))
#
# NameError: name 'raw_text' is not defined

# %%
import spacy
import pandas as pd
from collections import Counter

# 1. Definimos la variable (El "input" que faltaba)
raw_text = """
La meritocracia es un concepto complejo. En mi comunidad, 
vemos que el esfuerzo no siempre se traduce en éxito debido 
a la corrupción y la falta de oportunidades. Necesitamos 
una estrategia más eficiente para el bienestar de todos.
"""

# 2. Cargamos el modelo (Ya debería estar instalado)
nlp = spacy.load("es_core_news_sm")

# 3. Procesamos (Aquí ya no dará error porque raw_text existe)
doc = nlp(raw_text)

# 4. Filtramos palabras clave (Virtuosismo técnico)
keywords = [token.text.lower() for token in doc if token.is_alpha and not token.is_stop]

# 5. Contamos y preparamos para el gráfico
most_common = Counter(keywords).most_common(10)
df_viz = pd.DataFrame(most_common, columns=['Concepto', 'Frecuencia'])

# Mostramos el resultado (en lugar de st.bar_chart si no estás en Streamlit)
print(df_viz)
# Out:
#        Concepto  Frecuencia
# 0  meritocracia           1
# 1      concepto           1
# 2      complejo           1
# 3     comunidad           1
# 4         vemos           1
# 5      esfuerzo           1
# 6       traduce           1
# 7         éxito           1
# 8    corrupción           1
# 9         falta           1

# %%
raw_text = """
Pese al repunte económico postpandemia, varios indicadores favorables se han estancado 
o agravado, y se estima que el crecimiento económico será lento y modesto en los próximos 
años. La pobreza ha vuelto a los niveles prepandemia en algunos países y en otros 
continúa incrementándose, y los mercados de trabajo no han logrado recuperarse plenamente, 
por lo que el desempleo y la informalidad en algunas naciones son superiores a los niveles 
de 2019. Además, CA es una de las regiones más vulnerables a los impactos del cambio 
climático, lo que ya ha provocado inmensas pérdidas económicas, destrucción de sistemas 
productivos, incremento de la inseguridad alimentaria y desplazamiento forzado de la población.
"""

# %%
# 3. Procesamos (Aquí ya no dará error porque raw_text existe)
doc = nlp(raw_text)

# 4. Filtramos palabras clave (Virtuosismo técnico)
keywords = [token.text.lower() for token in doc if token.is_alpha and not token.is_stop]

# 5. Contamos y preparamos para el gráfico
most_common = Counter(keywords).most_common(10)
df_viz = pd.DataFrame(most_common, columns=['Concepto', 'Frecuencia'])

# Mostramos el resultado (en lugar de st.bar_chart si no estás en Streamlit)
print(df_viz)
# Out:
#        Concepto  Frecuencia
# 0     económico           2
# 1       niveles           2
# 2          pese           1
# 3       repunte           1
# 4  postpandemia           1
# 5   indicadores           1
# 6    favorables           1
# 7     estancado           1
# 8      agravado           1
# 9        estima           1

# %%
# 2. Procesamiento NLP
nlp = spacy.load("es_core_news_sm")
doc = nlp(raw_text)

# 3. Limpieza: Solo nos quedan sustantivos y adjetivos (la "carne" del discurso)
# Filtramos stop words y puntuación
tokens_limpios = [t.text.lower() for t in doc if (t.pos_ in ['NOUN', 'ADJ']) and not t.is_stop]

# 4. Análisis de CO-OCURRENCIA (Bigramas: parejas de palabras)
# Esto nos dice qué conceptos están ligados
bigramas = [f"{tokens_limpios[i]} + {tokens_limpios[i+1]}" for i in range(len(tokens_limpios)-1)]
frecuencia_relaciones = Counter(bigramas).most_common(10)

# 5. Visualización Estratégica
df_relaciones = pd.DataFrame(frecuencia_relaciones, columns=['Vínculo Conceptual', 'Frecuencia'])
print("--- RELACIONES DETECTADAS EN EL DISCURSO ---")
print(df_relaciones)
# Out:
# --- RELACIONES DETECTADAS EN EL DISCURSO ---
#          Vínculo Conceptual  Frecuencia
# 0            pese + repunte           1
# 1       repunte + económico           1
# 2   económico + indicadores           1
# 3  indicadores + favorables           1
# 4     favorables + agravado           1
# 5    agravado + crecimiento           1
# 6   crecimiento + económico           1
# 7         económico + lento           1
# 8           lento + modesto           1
# 9            modesto + años           1
